# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.formula.api import ols
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (3.1.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
houses = pd.read_csv('/Users/rachyc/Desktop/kc_house_data.csv')

# %%
houses.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180  \
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement
# 0      5650     1.0           0     0  ...      7        1180              0  \
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15
# 0      1955             0    98178  47.5112 -122.257           1340  \
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
houses['date'] = pd.to_datetime(houses['date'])

# %%
houses
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180  \
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above
# 0          5650     1.0           0     0  ...      7        1180  \
# 1          7242     2.0           0     0  ...      7        2170
# 2         10000     1.0           0     0  ...      6         770
# 3          5000     1.0           0     0  ...      7        1050
# 4          8080     1.0           0     0  ...      8        1680
# ...         ...     ...         ...   ...  ...    ...         ...
# 21608      1131     3.0           0     0  ...      8        1530
# 21609      5813     2.0           0     0  ...      8        2310
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long
# 0                  0      1955             0    98178  47.5112 -122.257  \
# 1                400      1951          1991    98125  47.7210 -122.319
# 2                  0      1933             0    98028  47.7379 -122.233
# 3                910      1965             0    98136  47.5208 -122.393
# 4                  0      1987             0    98074  47.6168 -122.045
# ...              ...       ...           ...      ...      ...      ...
# 21608              0      2009             0    98103  47.6993 -122.346
# 21609              0      2014             0    98146  47.5107 -122.362
# 21610              0      2009             0    98144  47.5944 -122.299
# 21611              0      2004             0    98027  47.5345 -122.069
# 21612              0      2008             0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21608           1530        1509
# 21609           1830        7200
# 21610           1020        2007
# 21611           1410        1287
# 21612           1020        1357
#
# [21613 rows x 21 columns]

# %%
houses['renovated'] = houses['yr_renovated'].apply(lambda x: 0 if x == 0 else 1)

# %%
#df_selected = houses.drop('date', axis=1)

# %%
# from sklearn.decomposition import PCA
# from sklearn.preprocessing import StandardScaler

# # Standardize the features
# scaler = StandardScaler()
# df_std = scaler.fit_transform(df_selected)

# # Perform PCA
# pca = PCA()
# df_pca = pca.fit_transform(df_std)

# # The transformed data is an array, convert it back into a dataframe
# df_pca = pd.DataFrame(df_pca, columns=[f'PC{i+1}' for i in range(len(houses.columns))])

# # Print the explained variance ratio
# print('Explained variance ratio:', pca.explained_variance_ratio_)

# # Print the cumulative explained variance ratio
# cumsum_variance = np.cumsum(pca.explained_variance_ratio_)
# print('Cumulative explained variance ratio:', cumsum_variance)

# # Show the first few rows of transformed dataframe
# df_pca.head()

# %%
def view(x):
    if x == 0 or x == 1:
        return 'Poor View'
    elif x == 2 and x == 3:
        return 'Average View'
    else:
        return 'Excellent View'

# %%
def condition(x):
    if x == 1 or x == 2:
        return 'Poor Condition'
    elif x == 3:
        return 'Average Condition'
    else:
        return 'Excellent Condition'

# %%
def grade(x):
    if 1<=x<=3:
        return 'Poor Quality'
    elif 4<=x<=10:
        return 'Average Quality'
    else:
        return 'Excellent Quality'

# %%
houses['view_score'] = houses['view'].apply(view)

# %%
houses['condition_score'] = houses['condition'].apply(condition)

# %%
houses['quality_score'] = houses['grade'].apply(grade)

# %%
houses
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180  \
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  yr_renovated  zipcode
# 0          5650     1.0           0     0  ...             0    98178  \
# 1          7242     2.0           0     0  ...          1991    98125
# 2         10000     1.0           0     0  ...             0    98028
# 3          5000     1.0           0     0  ...             0    98136
# 4          8080     1.0           0     0  ...             0    98074
# ...         ...     ...         ...   ...  ...           ...      ...
# 21608      1131     3.0           0     0  ...             0    98103
# 21609      5813     2.0           0     0  ...             0    98146
# 21610      1350     2.0           0     0  ...             0    98144
# 21611      2388     2.0           0     0  ...             0    98027
# 21612      1076     2.0           0     0  ...             0    98144
#
#            lat     long  sqft_living15  sqft_lot15  renovated  view_score
# 0      47.5112 -122.257           1340        5650          0   Poor View  \
# 1      47.7210 -122.319           1690        7639          1   Poor View
# 2      47.7379 -122.233           2720        8062          0   Poor View
# 3      47.5208 -122.393           1360        5000          0   Poor View
# 4      47.6168 -122.045           1800        7503          0   Poor View
# ...        ...      ...            ...         ...        ...         ...
# 21608  47.6993 -122.346           1530        1509          0   Poor View
# 21609  47.5107 -122.362           1830        7200          0   Poor View
# 21610  47.5944 -122.299           1020        2007          0   Poor View
# 21611  47.5345 -122.069           1410        1287          0   Poor View
# 21612  47.5941 -122.299           1020        1357          0   Poor View
#
#            condition_score    quality_score
# 0        Average Condition  Average Quality
# 1        Average Condition  Average Quality
# 2        Average Condition  Average Quality
# 3      Excellent Condition  Average Quality
# 4        Average Condition  Average Quality
# ...                    ...              ...
# 21608    Average Condition  Average Quality
# 21609    Average Condition  Average Quality
# 21610    Average Condition  Average Quality
# 21611    Average Condition  Average Quality
# 21612    Average Condition  Average Quality
#
# [21613 rows x 25 columns]

# %%
zipcode_dummies = pd.get_dummies(houses['zipcode'], prefix='zipcode')

# %%
houses = pd.concat([houses, zipcode_dummies], axis=1)

# %%
houses
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180  \
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  zipcode_98146  zipcode_98148
# 0          5650     1.0           0     0  ...          False          False  \
# 1          7242     2.0           0     0  ...          False          False
# 2         10000     1.0           0     0  ...          False          False
# 3          5000     1.0           0     0  ...          False          False
# 4          8080     1.0           0     0  ...          False          False
# ...         ...     ...         ...   ...  ...            ...            ...
# 21608      1131     3.0           0     0  ...          False          False
# 21609      5813     2.0           0     0  ...           True          False
# 21610      1350     2.0           0     0  ...          False          False
# 21611      2388     2.0           0     0  ...          False          False
# 21612      1076     2.0           0     0  ...          False          False
#
#        zipcode_98155  zipcode_98166  zipcode_98168  zipcode_98177
# 0              False          False          False          False  \
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 21608          False          False          False          False
# 21609          False          False          False          False
# 21610          False          False          False          False
# 21611          False          False          False          False
# 21612          False          False          False          False
#
#        zipcode_98178  zipcode_98188  zipcode_98198  zipcode_98199
# 0               True          False          False          False
# 1              False          False          False          False
# 2              False          False          False          False
# 3              False          False          False          False
# 4              False          False          False          False
# ...              ...            ...            ...            ...
# 21608          False          False          False          False
# 21609          False          False          False          False
# 21610          False          False          False          False
# 21611          False          False          False          False
# 21612          False          False          False          False
#
# [21613 rows x 95 columns]

# %%
plt.scatter(houses['price'],houses['sqft_living'])

# %%
houses.groupby('grade')['price'].count().sort_values(ascending=False).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='grade'>

# %%
results = ols("price ~ sqft_living + sqft_living15 + sqft_lot15 + grade + condition + bedrooms + bathrooms", data=houses).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.559
# Method:                 Least Squares   F-statistic:                     3914.
# Date:                Sun, 09 Jul 2023   Prob (F-statistic):               0.00
# Time:                        21:20:34   Log-Likelihood:            -2.9876e+05
# No. Observations:               21613   AIC:                         5.975e+05
# Df Residuals:                   21605   BIC:                         5.976e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -7.253e+05   1.81e+04    -40.123      0.000   -7.61e+05    -6.9e+05
# sqft_living     219.7334      3.931     55.891      0.000     212.027     227.439
# sqft_living15    17.7667      3.935      4.515      0.000      10.054      25.479
# sqft_lot15       -0.7363      0.062    -11.795      0.000      -0.859      -0.614
# grade          9.843e+04   2419.056     40.689      0.000    9.37e+04    1.03e+05
# condition      6.517e+04   2603.898     25.029      0.000    6.01e+04    7.03e+04
# bedrooms      -4.561e+04   2266.334    -20.124      0.000   -5.01e+04   -4.12e+04
# bathrooms     -1.874e+04   3453.687     -5.427      0.000   -2.55e+04    -1.2e+04
# ==============================================================================
# Omnibus:                    16770.128   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           992356.757
# Skew:                           3.240   Prob(JB):                         0.00
# Kurtosis:                      35.557   Cond. No.                     3.32e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.32e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
pred_vals = results.predict(houses[['sqft_living','sqft_living15','sqft_lot15','grade','condition','bedrooms','bathrooms']])

# %%
res = pd.concat([pred_vals.to_frame().rename(columns={0:'y_hat'}),houses['price']], axis=1)

# %%
res
# Out:
#                y_hat     price
# 0      282571.952988  221900.0
# 1      569327.455379  538000.0
# 2      162402.477854  180000.0
# 3      502050.535340  604000.0
# 4      478933.870259  510000.0
# ...              ...       ...
# 21608  436219.373904  360000.0
# 21609  563142.679920  400000.0
# 21610  294705.524260  402101.0
# 21611  449632.168619  400000.0
# 21612  295184.142756  325000.0
#
# [21613 rows x 2 columns]

# %%
res['error'] = res['y_hat'] - res['price']

# %%
res.head(1)
# Out:
#            y_hat     price         error
# 0  282571.952988  221900.0  60671.952988

# %%
res['sq_error'] = res['error']**2

# %%
np.sqrt(res['sq_error'].mean())
# Out:
# 243773.17698815008

# %%
houses.describe()
# Out:
#                  id                           date         price
# count  2.161300e+04                          21613  2.161300e+04  \
# mean   4.580302e+09  2014-10-29 04:38:01.959931648  5.400881e+05
# min    1.000102e+06            2014-05-02 00:00:00  7.500000e+04
# 25%    2.123049e+09            2014-07-22 00:00:00  3.219500e+05
# 50%    3.904930e+09            2014-10-16 00:00:00  4.500000e+05
# 75%    7.308900e+09            2015-02-17 00:00:00  6.450000e+05
# max    9.900000e+09            2015-05-27 00:00:00  7.700000e+06
# std    2.876566e+09                            NaN  3.671272e+05
#
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors
# count  21613.000000  21613.000000  21613.000000  2.161300e+04  21613.000000  \
# mean       3.370842      2.114757   2079.899736  1.510697e+04      1.494309
# min        0.000000      0.000000    290.000000  5.200000e+02      1.000000
# 25%        3.000000      1.750000   1427.000000  5.040000e+03      1.000000
# 50%        3.000000      2.250000   1910.000000  7.618000e+03      1.500000
# 75%        4.000000      2.500000   2550.000000  1.068800e+04      2.000000
# max       33.000000      8.000000  13540.000000  1.651359e+06      3.500000
# std        0.930062      0.770163    918.440897  4.142051e+04      0.539989
#
#          waterfront          view  ...    sqft_above  sqft_basement
# count  21613.000000  21613.000000  ...  21613.000000   21613.000000  \
# mean       0.007542      0.234303  ...   1788.390691     291.509045
# min        0.000000      0.000000  ...    290.000000       0.000000
# 25%        0.000000      0.000000  ...   1190.000000       0.000000
# 50%        0.000000      0.000000  ...   1560.000000       0.000000
# 75%        0.000000      0.000000  ...   2210.000000     560.000000
# max        1.000000      4.000000  ...   9410.000000    4820.000000
# std        0.086517      0.766318  ...    828.090978     442.575043
#
#            yr_built  yr_renovated       zipcode           lat          long
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000  \
# mean    1971.005136     84.402258  98077.939805     47.560053   -122.213896
# min     1900.000000      0.000000  98001.000000     47.155900   -122.519000
# 25%     1951.000000      0.000000  98033.000000     47.471000   -122.328000
# 50%     1975.000000      0.000000  98065.000000     47.571800   -122.230000
# 75%     1997.000000      0.000000  98118.000000     47.678000   -122.125000
# max     2015.000000   2015.000000  98199.000000     47.777600   -121.315000
# std       29.373411    401.679240     53.505026      0.138564      0.140828
#
#        sqft_living15     sqft_lot15     renovated
# count   21613.000000   21613.000000  21613.000000
# mean     1986.552492   12768.455652      0.042289
# min       399.000000     651.000000      0.000000
# 25%      1490.000000    5100.000000      0.000000
# 50%      1840.000000    7620.000000      0.000000
# 75%      2360.000000   10083.000000      0.000000
# max      6210.000000  871200.000000      1.000000
# std       685.391304   27304.179631      0.201253
#
# [8 rows x 22 columns]

# %%
plt.hist(res['error'])
# Out:
# (array([3.0000e+00, 0.0000e+00, 4.0000e+00, 2.0000e+00, 2.3000e+01,
#         6.1000e+01, 2.5300e+02, 4.4870e+03, 1.6572e+04, 2.0800e+02]),
#  array([-4597324.77294593, -4036658.66283823, -3475992.55273054,
#         -2915326.44262285, -2354660.33251516, -1793994.22240747,
#         -1233328.11229978,  -672662.00219208,  -111995.89208439,
#           448670.2180233 ,  1009336.32813099]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(houses['price'])
# Out:
# (array([1.9021e+04, 2.1480e+03, 3.1600e+02, 9.0000e+01, 2.6000e+01,
#         4.0000e+00, 4.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([  75000.,  837500., 1600000., 2362500., 3125000., 3887500.,
#         4650000., 5412500., 6175000., 6937500., 7700000.]),
#  <BarContainer object of 10 artists>)

# %%
houses.describe()
# Out:
#                  id                           date         price
# count  2.161300e+04                          21613  2.161300e+04  \
# mean   4.580302e+09  2014-10-29 04:38:01.959931648  5.400881e+05
# min    1.000102e+06            2014-05-02 00:00:00  7.500000e+04
# 25%    2.123049e+09            2014-07-22 00:00:00  3.219500e+05
# 50%    3.904930e+09            2014-10-16 00:00:00  4.500000e+05
# 75%    7.308900e+09            2015-02-17 00:00:00  6.450000e+05
# max    9.900000e+09            2015-05-27 00:00:00  7.700000e+06
# std    2.876566e+09                            NaN  3.671272e+05
#
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors
# count  21613.000000  21613.000000  21613.000000  2.161300e+04  21613.000000  \
# mean       3.370842      2.114757   2079.899736  1.510697e+04      1.494309
# min        0.000000      0.000000    290.000000  5.200000e+02      1.000000
# 25%        3.000000      1.750000   1427.000000  5.040000e+03      1.000000
# 50%        3.000000      2.250000   1910.000000  7.618000e+03      1.500000
# 75%        4.000000      2.500000   2550.000000  1.068800e+04      2.000000
# max       33.000000      8.000000  13540.000000  1.651359e+06      3.500000
# std        0.930062      0.770163    918.440897  4.142051e+04      0.539989
#
#          waterfront          view  ...    sqft_above  sqft_basement
# count  21613.000000  21613.000000  ...  21613.000000   21613.000000  \
# mean       0.007542      0.234303  ...   1788.390691     291.509045
# min        0.000000      0.000000  ...    290.000000       0.000000
# 25%        0.000000      0.000000  ...   1190.000000       0.000000
# 50%        0.000000      0.000000  ...   1560.000000       0.000000
# 75%        0.000000      0.000000  ...   2210.000000     560.000000
# max        1.000000      4.000000  ...   9410.000000    4820.000000
# std        0.086517      0.766318  ...    828.090978     442.575043
#
#            yr_built  yr_renovated       zipcode           lat          long
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000  \
# mean    1971.005136     84.402258  98077.939805     47.560053   -122.213896
# min     1900.000000      0.000000  98001.000000     47.155900   -122.519000
# 25%     1951.000000      0.000000  98033.000000     47.471000   -122.328000
# 50%     1975.000000      0.000000  98065.000000     47.571800   -122.230000
# 75%     1997.000000      0.000000  98118.000000     47.678000   -122.125000
# max     2015.000000   2015.000000  98199.000000     47.777600   -121.315000
# std       29.373411    401.679240     53.505026      0.138564      0.140828
#
#        sqft_living15     sqft_lot15     renovated
# count   21613.000000   21613.000000  21613.000000
# mean     1986.552492   12768.455652      0.042289
# min       399.000000     651.000000      0.000000
# 25%      1490.000000    5100.000000      0.000000
# 50%      1840.000000    7620.000000      0.000000
# 75%      2360.000000   10083.000000      0.000000
# max      6210.000000  871200.000000      1.000000
# std       685.391304   27304.179631      0.201253
#
# [8 rows x 22 columns]

# %%
plt.scatter(houses['sqft_living'],res['error'])

# %%
plt.scatter(houses['condition'],res['error'])

# %%
plt.scatter(houses['sqft_living15'],res['error'])

# %%
import scipy.stats as stats
fig = plt.figure()
ax = fig.add_subplot(111)
stats.probplot(res['error'], dist='norm', plot=ax)
# Out:
# ((array([-3.99703558, -3.78181236, -3.66408326, ...,  3.66408326,
#           3.78181236,  3.99703558]),
#   array([-4597324.77294593, -4564750.8086482 , -4331759.74273219, ...,
#            882655.23404376,   976246.69192951,  1009336.32813099])),
#  (220755.07187927215, 9.53333866310039e-10, 0.9054145307445352))

# %%
res
# Out:
#                y_hat     price          error      sq_error
# 0      282571.952988  221900.0   60671.952988  3.681086e+09
# 1      569327.455379  538000.0   31327.455379  9.814095e+08
# 2      162402.477854  180000.0  -17597.522146  3.096728e+08
# 3      502050.535340  604000.0 -101949.464660  1.039369e+10
# 4      478933.870259  510000.0  -31066.129741  9.651044e+08
# ...              ...       ...            ...           ...
# 21608  436219.373904  360000.0   76219.373904  5.809393e+09
# 21609  563142.679920  400000.0  163142.679920  2.661553e+10
# 21610  294705.524260  402101.0 -107395.475740  1.153379e+10
# 21611  449632.168619  400000.0   49632.168619  2.463352e+09
# 21612  295184.142756  325000.0  -29815.857244  8.889853e+08
#
# [21613 rows x 4 columns]

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 95 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  int64
#  1   date             21613 non-null  datetime64[ns]
#  2   price            21613 non-null  float64
#  3   bedrooms         21613 non-null  int64
#  4   bathrooms        21613 non-null  float64
#  5   sqft_living      21613 non-null  int64
#  6   sqft_lot         21613 non-null  int64
#  7   floors           21613 non-null  float64
#  8   waterfront       21613 non-null  int64
#  9   view             21613 non-null  int64
#  10  condition        21613 non-null  int64
#  11  grade            21613 non-null  int64
#  12  sqft_above       21613 non-null  int64
#  13  sqft_basement    21613 non-null  int64
#  14  yr_built         21613 non-null  int64
#  15  yr_renovated     21613 non-null  int64
#  16  zipcode          21613 non-null  int64
#  17  lat              21613 non-null  float64
#  18  long             21613 non-null  float64
#  19  sqft_living15    21613 non-null  int64
#  20  sqft_lot15       21613 non-null  int64
#  21  renovated        21613 non-null  int64
#  22  view_score       21613 non-null  object
#  23  condition_score  21613 non-null  object
#  24  quality_score    21613 non-null  object
#  25  zipcode_98001    21613 non-null  bool
#  26  zipcode_98002    21613 non-null  bool
#  27  zipcode_98003    21613 non-null  bool
#  28  zipcode_98004    21613 non-null  bool
#  29  zipcode_98005    21613 non-null  bool
#  30  zipcode_98006    21613 non-null  bool
#  31  zipcode_98007    21613 non-null  bool
#  32  zipcode_98008    21613 non-null  bool
#  33  zipcode_98010    21613 non-null  bool
#  34  zipcode_98011    21613 non-null  bool
#  35  zipcode_98014    21613 non-null  bool
#  36  zipcode_98019    21613 non-null  bool
#  37  zipcode_98022    21613 non-null  bool
#  38  zipcode_98023    21613 non-null  bool
#  39  zipcode_98024    21613 non-null  bool
#  40  zipcode_98027    21613 non-null  bool
#  41  zipcode_98028    21613 non-null  bool
#  42  zipcode_98029    21613 non-null  bool
#  43  zipcode_98030    21613 non-null  bool
#  44  zipcode_98031    21613 non-null  bool
#  45  zipcode_98032    21613 non-null  bool
#  46  zipcode_98033    21613 non-null  bool
#  47  zipcode_98034    21613 non-null  bool
#  48  zipcode_98038    21613 non-null  bool
#  49  zipcode_98039    21613 non-null  bool
#  50  zipcode_98040    21613 non-null  bool
#  51  zipcode_98042    21613 non-null  bool
#  52  zipcode_98045    21613 non-null  bool
#  53  zipcode_98052    21613 non-null  bool
#  54  zipcode_98053    21613 non-null  bool
#  55  zipcode_98055    21613 non-null  bool
#  56  zipcode_98056    21613 non-null  bool
#  57  zipcode_98058    21613 non-null  bool
#  58  zipcode_98059    21613 non-null  bool
#  59  zipcode_98065    21613 non-null  bool
#  60  zipcode_98070    21613 non-null  bool
#  61  zipcode_98072    21613 non-null  bool
#  62  zipcode_98074    21613 non-null  bool
#  63  zipcode_98075    21613 non-null  bool
#  64  zipcode_98077    21613 non-null  bool
#  65  zipcode_98092    21613 non-null  bool
#  66  zipcode_98102    21613 non-null  bool
#  67  zipcode_98103    21613 non-null  bool
#  68  zipcode_98105    21613 non-null  bool
#  69  zipcode_98106    21613 non-null  bool
#  70  zipcode_98107    21613 non-null  bool
#  71  zipcode_98108    21613 non-null  bool
#  72  zipcode_98109    21613 non-null  bool
#  73  zipcode_98112    21613 non-null  bool
#  74  zipcode_98115    21613 non-null  bool
#  75  zipcode_98116    21613 non-null  bool
#  76  zipcode_98117    21613 non-null  bool
#  77  zipcode_98118    21613 non-null  bool
#  78  zipcode_98119    21613 non-null  bool
#  79  zipcode_98122    21613 non-null  bool
#  80  zipcode_98125    21613 non-null  bool
#  81  zipcode_98126    21613 non-null  bool
#  82  zipcode_98133    21613 non-null  bool
#  83  zipcode_98136    21613 non-null  bool
#  84  zipcode_98144    21613 non-null  bool
#  85  zipcode_98146    21613 non-null  bool
#  86  zipcode_98148    21613 non-null  bool
#  87  zipcode_98155    21613 non-null  bool
#  88  zipcode_98166    21613 non-null  bool
#  89  zipcode_98168    21613 non-null  bool
#  90  zipcode_98177    21613 non-null  bool
#  91  zipcode_98178    21613 non-null  bool
#  92  zipcode_98188    21613 non-null  bool
#  93  zipcode_98198    21613 non-null  bool
#  94  zipcode_98199    21613 non-null  bool
# dtypes: bool(70), datetime64[ns](1), float64(5), int64(16), object(3)
# memory usage: 5.6+ MB

# %%
daily_dataset = houses.set_index('date').resample("D").agg({'sqft_living':'max','sqft_lot':'max','bedrooms':'mean','price':'sum'})

# %%
daily_dataset
# Out:
#             sqft_living  sqft_lot  bedrooms       price
# date
# 2014-05-02       3660.0  125452.0  3.402985  35258850.0
# 2014-05-03       2920.0   14054.0  3.000000   1867880.0
# 2014-05-04       2850.0    9933.0  3.200000   2883450.0
# 2014-05-05      13540.0  307752.0  3.523810  48798843.0
# 2014-05-06       4510.0  117612.0  3.493976  44325976.0
# ...                 ...       ...       ...         ...
# 2015-05-23          NaN       NaN       NaN         0.0
# 2015-05-24       1390.0    6670.0  2.000000    445500.0
# 2015-05-25          NaN       NaN       NaN         0.0
# 2015-05-26          NaN       NaN       NaN         0.0
# 2015-05-27       3750.0    5000.0  4.000000   1310000.0
#
# [391 rows x 4 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler
from sklearn.linear_model import LinearRegression, ElasticNet, Ridge, Lasso
from sklearn.impute import SimpleImputer
import numpy as np

# %%
houses.head(2)
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180  \
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
#
#    sqft_lot  floors  waterfront  view  ...  zipcode_98146  zipcode_98148
# 0      5650     1.0           0     0  ...          False          False  \
# 1      7242     2.0           0     0  ...          False          False
#
#    zipcode_98155  zipcode_98166  zipcode_98168  zipcode_98177  zipcode_98178
# 0          False          False          False          False           True  \
# 1          False          False          False          False          False
#
#    zipcode_98188  zipcode_98198  zipcode_98199
# 0          False          False          False
# 1          False          False          False
#
# [2 rows x 95 columns]

# %%
categorical_features = ['waterfront','view_score', 'quality_score']
numerical_features = ['sqft_living','sqft_living15', 'bedrooms']
target = 'price'

# %%
houses[['waterfront','view_score', 'quality_score','sqft_living','sqft_living15','bedrooms']]
# Out:
#        waterfront view_score    quality_score  sqft_living  sqft_living15
# 0               0  Poor View  Average Quality         1180           1340  \
# 1               0  Poor View  Average Quality         2570           1690
# 2               0  Poor View  Average Quality          770           2720
# 3               0  Poor View  Average Quality         1960           1360
# 4               0  Poor View  Average Quality         1680           1800
# ...           ...        ...              ...          ...            ...
# 21608           0  Poor View  Average Quality         1530           1530
# 21609           0  Poor View  Average Quality         2310           1830
# 21610           0  Poor View  Average Quality         1020           1020
# 21611           0  Poor View  Average Quality         1600           1410
# 21612           0  Poor View  Average Quality         1020           1020
#
#        bedrooms
# 0             3
# 1             3
# 2             2
# 3             4
# 4             3
# ...         ...
# 21608         3
# 21609         4
# 21610         2
# 21611         3
# 21612         2
#
# [21613 rows x 6 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(houses[categorical_features + numerical_features]
                                                    ,houses[target],
                                                    test_size = 0.3, random_state=1234)

# %%
cat_transformer = Pipeline(steps = [('onehot', OneHotEncoder(handle_unknown='ignore'))])
num_transformer = Pipeline(steps = [('scaler', StandardScaler())])

# %%
preprocessor = ColumnTransformer(transformers = [('cat',cat_transformer, categorical_features),
                                                 ('num', num_transformer, numerical_features)])

# %%
linear_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
linear_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['waterfront', 'view_score',
#                                                    'quality_score']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sqft_living',
#                                                    'sqft_living15',
#                                                    'bedrooms'])])),
#                 ('regressor', LinearRegression())])

# %%
pred = linear_regression.predict(X_test)

# %%
pred
# Out:
# array([ 517632.,  617472., 1389440., ...,  671232.,  510848.,  610560.])

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(pred,y_test))
# Out:
# 233346.87995758557

# %%
ridge_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', Ridge(alpha=3.0))
])

# %%
ridge_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['waterfront', 'view_score',
#                                                    'quality_score']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sqft_living',
#                                                    'sqft_living15',
#                                                    'bedrooms'])])),
#                 ('regressor', Ridge(alpha=3.0))])

# %%
pred_ridge = ridge_regression.predict(X_test)

# %%
np.sqrt(mean_squared_error(pred_ridge,y_test))
# Out:
# 233332.88285670598

# %%
lasso_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', Lasso(alpha=1.0))
])

# %%
lasso_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['waterfront', 'view_score',
#                                                    'quality_score']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sqft_living',
#                                                    'sqft_living15',
#                                                    'bedrooms'])])),
#                 ('regressor', Lasso())])

# %%
lasso_pred = lasso_regression.predict(X_test)

# %%
np.sqrt(mean_squared_error(lasso_pred, y_test))
# Out:
# 233348.12774301117

# %%
elasticnet_regression = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('regressor', ElasticNet(alpha=1.0, l1_ratio=0.8))
])

# %%
elasticnet_regression.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['waterfront', 'view_score',
#                                                    'quality_score']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sqft_living',
#                                                    'sqft_living15',
#                                                    'bedrooms'])])),
#                 ('regressor', ElasticNet(l1_ratio=0.8))])

# %%
elasticnet_pred = elasticnet_regression.predict(X_test)

# %%
np.sqrt(mean_squared_error(elasticnet_pred, y_test))
# Out:
# 247790.42271729794

# %%
y_test
# Out:
# 12432     485000.0
# 7793      358000.0
# 13435     716500.0
# 1821      367500.0
# 12449     544000.0
#            ...
# 2596     1065000.0
# 21161     459990.0
# 20133     388500.0
# 11130     530000.0
# 16762     449400.0
# Name: price, Length: 6484, dtype: float64

# %%
elastic_net_pred = pd.concat([pd.DataFrame(elasticnet_pred).rename(columns={0:'pred'}),y_test.reset_index().drop('index',axis=1).rename(columns={0:'price'})], axis=1)

# %%
elastic_net_pred['res'] = elastic_net_pred['pred'] - elastic_net_pred['price']

# %%
X_test
# Out:
#        waterfront view_score      quality_score  sqft_living  sqft_living15
# 12432           0  Poor View    Average Quality         2030           2030  \
# 7793            0  Poor View    Average Quality         2510           1870
# 13435           0  Poor View  Excellent Quality         3630           4440
# 1821            0  Poor View    Average Quality         1660           1320
# 12449           0  Poor View    Average Quality         2030           1780
# ...           ...        ...                ...          ...            ...
# 2596            0  Poor View    Average Quality         1890           2180
# 21161           0  Poor View    Average Quality         2680           2990
# 20133           0  Poor View    Average Quality         2718           2667
# 11130           0  Poor View    Average Quality         1980           2120
# 16762           0  Poor View    Average Quality         2490           2470
#
#        bedrooms
# 12432         3
# 7793          3
# 13435         5
# 1821          3
# 12449         4
# ...         ...
# 2596          2
# 21161         3
# 20133         4
# 11130         3
# 16762         4
#
# [6484 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(X_test['sqft_living'],elastic_net_pred['res'])

# %% [markdown]
# 1. Build a regression model to predict the price of a house. You may choose between Ordinary Least Squares Regression, LASSO, Ridge or Elastic Net.
# You may need to clean and transform the data, including feature engineering, creating dummy variables, or using dimensionality reduction.
# Be sure to explain why you chose the approach you did, and why it's the best approach for the data provided.
#
# I did some feature engineering.
# Firstly, I transformed date column to a datetime data format, which makes the table easy to read.
# Secondly, I converted yr_renovated into a binary variable that clearly marks whether a house has been renovated or not. Thirdly, I created 3 functions to classify good view/poor view, good condition/poor condition and good quality/poor quality in terms of buidling construction and design. Then I created 3 new columns by applying those 3 functions to "view","grade" and "condition" columns. Therefore, I can clearly know how the buidling values in terms of view, conditin and quality.
# Lastly, I created dummy variables for zipcode, which allows me to include geographic location as a factor when analysing the model.
#
# 2. Evaluate the model using techniques covered in class and explain the results. How do you know this is the best model you can build, given the tools you have?
#
# I first created a Ordinary Least Squares Regression. An R-squared of 0.559 means that about 55.9% of the variance in house prices is explained by the model. Prob (F-statistic) is zero, which indicates that the model is statistically significant.
#
# The square footage of living space (sqft_living 219.7334), square footage of interior housing living space for the nearest 15 neighbors (sqft_living15 17.7667), the overall grade given to the housing unit (grade 9.843e+04), and overall condition of the house (condition 6.517e+04) have a positive association with price. This means that as these variables increase, the price of the house tends to increase as well.
# Specifically, For each additional square foot of living space, the price of a house increases by approximately $219.73. For each additional square foot in the interior housing living space for the nearest 15 neighbors(sqftliving15), the price increases by approximately $17.77. For each increase in the overall grade given to the housing unit (grade), the price increases by approximately $98,430. For each increase in the overall condition of the house (condition), the price increases by approximately $65,170.
#
# The number of bedrooms (bedrooms) and bathrooms (bathrooms) and the coefficient for the square footage of the land lots of the nearest 15 neighbors (sqft_lot15) have a negative association with price. This suggests that as these variables increase, the price of the house tends to decrease.
# Specifically, For each additional bedroom (bedrooms), the price decreases by approximately $45,610. For each additional bathroom (bathrooms), the price decreases by approximately $18,740. For each additional square foot of the land lots of the nearest 15 neighbors (sqft_lot15), the price decreases by approximately $0.74.
#
# I calculated the Root Mean Squared Error (RMSE) of the four models(Ordinary Least Squares Regression, LASSO, Ridge or Elastic Net), which is the average squared differences between the predicted and actual values. What I found out is that Ridge is the best model to perform, which got the lowest number 233332.88285670598. The Elastic Net is the worst model to perform, which got the highest number 247790.42271729794.
#
# 3. Explain the results to a business executive. What are the main drivers of house prices in King City? And how much do these drivers impact the price?
#
# The main drivers of the house prices in King City would be
# 1) Size of the Living Space (sqft_living). For each additional square foot of living space, we expect the house price to increase by approximately $219. This suggests that larger houses, in terms of living space, tend to be more expensive.
# 2) Grade of the House (grade). For each unit increase in the grade, we expect the house price to increase by roughly $98,430. Therefore, houses of superior quality and design fetch higher prices in the market.
# 3) Condition of the House (condition). For each unit increase in the condition (based on a scale), we expect the house price to rise by approximately $65,170. Well-maintained houses with fewer required repairs tend to be more valuable.
# 4) Size of Nearby Houses (sqft_living15). For each additional square foot in the average living space of the 15 closest houses, we expect the price of the house in question to increase by approximately $17.77. This suggests that houses in neighborhoods with larger houses (in terms of living space) tend to be more expensive. I think it is because larger houses nearby often indicate a more affluent or desirable area.
